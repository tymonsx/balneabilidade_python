# %%
import os
import sys
import urllib.request

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from stellargraph.layer import GCN_LSTM
import stellargraph as sg

# %%
parser = (lambda x:datetime.datetime.strptime(x, '%Y.%m.%d')) 
df = pd.read_csv('sp_beaches_update.csv', parse_dates=['Date'])
df=df.loc[~df['Enterococcus'].isnull()]
#remover a praia do Leste, da cidade de iguape, pois esta praia sumiu por erosão em 2012
#remover a Lagoa Prumirim, da cidade de Ubatuba, pois esta praia possui somente 3 medições
df = df.loc[df['Beach']!='DO LESTE'].loc[df['Beach']!='LAGOA PRUMIRIM']
df['praia'] = df[['City', 'Beach']].apply(lambda x: ' - '.join(x), axis=1)
print(f'Numero de praias: {len(df.praia.unique())}')
df = df.sort_values(by=['praia'])
df = df.sort_values(by=['Date'])
df = df[['Date','praia','Enterococcus']]
df.shape
# Out:
# Numero de praias: 174
# (69016, 3)

# %%
for praia in df.praia.unique():
    df_aux = df.loc[df['praia']==praia]
    #print(f'Praia: {praia} - Qtd Medições: {len(df_aux.Date)}')
    print(praia)
# Out:
# BERTIOGA - BORACÉIA - COL. MARISTA
# SÃO VICENTE - ITARARÉ (POSTO 2)
# UBATUBA - TENÓRIO
# BERTIOGA - ENSEADA - INDAIÁ
# MONGAGUÁ - AGENOR DE CAMPOS
# CARAGUATATUBA - COCANHA
# SÃO VICENTE - MILIONÁRIOS
# SÃO VICENTE - PRAIA DA DIVISA
# CARAGUATATUBA - MASSAGUAÇU (R. MARIA CARLOTA)
# ITANHAÉM - SUARÃO
# ITANHAÉM - SONHO
# MONGAGUÁ - CENTRAL
# ILHA ANCHIETA - PRAIA DE FORA
# ITANHAÉM - PRAIA DOS PESCADORES
# GUARUJÁ - ENSEADA (R. CHILE)
# ITANHAÉM - PARQUE BALNEÁRIO
# SÃO VICENTE - PRAINHA ( AV. SANTINO BRITO)
# ITANHAÉM - JARDIM SÃO FERNANDO
# UBATUBA - DOMINGAS DIAS
# CARAGUATATUBA - PORTO NOVO
# ITANHAÉM - JARDIM CIBRATEL
# UBATUBA - DURA
# ITANHAÉM - ESTÂNCIA BALNEÁRIA
# SÃO VICENTE - PRAIA DA ILHA PORCHAT
# MONGAGUÁ - ITAPOÃ - VILA SÃO PAULO
# GUARUJÁ - ENSEADA (ESTR. DE PERNAMBUCO)
# CARAGUATATUBA - PRAINHA
# PRAIA GRANDE - AVIAÇÃO
# IGUAPE - JURÉIA
# SÃO SEBASTIÃO - SANTIAGO
# PERUÍBE - PRAINHA
# PERUÍBE - PERUÍBE (R. ICARAÍBA)
# ILHA ANCHIETA - PRAIA DAS PALMAS
# SÃO SEBASTIÃO - SAÍ
# PERUÍBE - PERUÍBE (PARQUE TURÍSTICO)
# CARAGUATATUBA - MOCOÓCA
# PERUÍBE - PERUÍBE (BALN. SÃO JOÃO BATISTA)
# PERUÍBE - PERUÍBE (AV. S. JOÃO)
# PERUÍBE - GUARAÚ
# SÃO SEBASTIÃO - SÃO FRANCISCO
# CARAGUATATUBA - CENTRO
# SÃO SEBASTIÃO - TOQUE-TOQUE GRANDE
# BERTIOGA - ENSEADA - R. RAFAEL COSTABILI
# MONGAGUÁ - VERA CRUZ
# MONGAGUÁ - SANTA EUGÊNIA
# CARAGUATATUBA - TABATINGA (250m  RIO TABATINGA)
# SÃO SEBASTIÃO - TOQUE-TOQUE PEQUENO
# SÃO SEBASTIÃO - UNA
# MONGAGUÁ - ITAÓCA
# SÃO VICENTE - GONZAGUINHA
# ITANHAÉM - CENTRO
# UBATUBA - SUNUNGA
# UBATUBA - ENSEADA
# UBATUBA - FÉLIX
# ILHABELA - ITAGUAÇU
# UBATUBA - MARANDUBA
# CARAGUATATUBA - PAN BRASIL
# ILHABELA - ILHA DAS CABRAS
# ILHABELA - GRANDE
# ILHA ANCHIETA - PRAIA DO PRESIDIO
# UBATUBA - PEREQUÊ-AÇU
# ILHABELA - FEITICEIRA
# UBATUBA - PEREQUÊ-MIRIM
# UBATUBA - PICINGUABA
# ILHABELA - CURRAL
# CARAGUATATUBA - MASSAGUAÇU (AV. M. H. CARVALHO)
# UBATUBA - SANTA RITA
# UBATUBA - PRUMIRIM
# BERTIOGA - BORACÉIA - SUL
# UBATUBA - PULSO
# ILHABELA - ARMAÇÃO
# ILHA COMPRIDA - PRAINHA (BALSA)
# ILHA COMPRIDA - PONTAL
# ILHA COMPRIDA - CENTRO
# ILHA ANCHIETA - PRAINHA DO LESTE
# UBATUBA - RIO  ITAMAMBUCA
# ILHA ANCHIETA - PRAIA DO SAPATEIRO
# CARAGUATATUBA - MARTIM DE SÁ
# SÃO SEBASTIÃO - PRETA DO NORTE
# ILHABELA - ITAQUANDUBA
# UBATUBA - LAGOINHA (R. ENGENHO VELHO)
# ITANHAÉM - CAMPOS ELÍSEOS
# UBATUBA - GRANDE
# BERTIOGA - ENSEADA - COLÔNIA DO SESC
# ITANHAÉM - BALNEÁRIO GAIVOTA
# ILHABELA - VIANA
# CARAGUATATUBA - INDAIÁ
# ILHABELA - SIRIÚBA
# UBATUBA - IPEROIG
# ILHA ANCHIETA - PRAIA DO ENGENHO
# GUARUJÁ - GUAIÚBA
# GUARUJÁ - PERNAMBUCO
# ILHABELA - SINO
# UBATUBA - ITAGUA (No1724 DA AV. LEOVEGILDO)
# UBATUBA - ITAGUÁ (No 230 DA AV. LEOVEGILDO)
# UBATUBA - SAPÉ
# ILHABELA - SACO DA CAPELA
# CARAGUATATUBA - LAGOA AZUL
# UBATUBA - ITAMAMBUCA
# ILHABELA - PORTINHO
# ILHABELA - PINTO
# ILHABELA - PEREQUÊ
# UBATUBA - LAGOINHA (CAMPING)
# GUARUJÁ - PEREQUÊ
# UBATUBA - LÁZARO
# SÃO SEBASTIÃO - PRETA
# ILHA ANCHIETA - PRAIA DO SUL
# SÃO SEBASTIÃO - GRANDE
# PRAIA GRANDE - GUILHERMINA
# BERTIOGA - GUARATUBA
# SÃO SEBASTIÃO - CAMBURI
# UBATUBA - VERMELHA DO NORTE
# SANTOS - EMBARÉ
# SÃO SEBASTIÃO - BALEIA
# CARAGUATATUBA - CAPRICÓRNIO
# SÃO SEBASTIÃO - ARRASTÃO
# PRAIA GRANDE - JARDIM SOLEMAR
# PRAIA GRANDE - VILA TUPI
# SANTOS - GONZAGA
# SANTOS - PONTA DA PRAIA
# BERTIOGA - ENSEADA - VISTA LINDA
# SÃO SEBASTIÃO - CAMBURIZINHO
# SÃO SEBASTIÃO - ENGENHO
# SÃO SEBASTIÃO - PAÚBA
# PRAIA GRANDE - MARACANÃ
# PRAIA GRANDE - VILA MIRIM
# GUARUJÁ - ENSEADA (AV. ATLÂNTICA)
# UBATUBA - VERMELHA
# SANTOS - JOSÉ MENINO (R. OLAVO BILAC)
# SÃO SEBASTIÃO - DESERTA
# SÃO SEBASTIÃO - MARESIAS
# SÃO SEBASTIÃO - CIGARRAS
# SÃO SEBASTIÃO - JUQUEÍ (TRAV. SIMÃO FAUSTINO)
# PRAIA GRANDE - OCIAN
# SANTOS - JOSÉ MENINO (R. FREDERICO OZANAN)
# SÃO SEBASTIÃO - JURÉIA DO NORTE
# PRAIA GRANDE - VILA CAIÇARA
# CUBATÃO - RIO PEREQUÊ
# SÃO SEBASTIÃO - PONTAL DA CRUZ
# SÃO SEBASTIÃO - JUQUEÍ (R. CRISTIANA)
# PRAIA GRANDE - REAL
# SÃO SEBASTIÃO - BORACÉIA - NORTE
# CARAGUATATUBA - PALMEIRAS
# PRAIA GRANDE - CANTO DO FORTE
# GUARUJÁ - PITANGUEIRAS (AV. PUGLISI)
# BERTIOGA - SÃO LOURENÇO (RUA 2)
# SÃO SEBASTIÃO - BAREQUEÇABA
# SÃO SEBASTIÃO - PRAINHA
# SANTOS - BOQUEIRÃO
# SÃO SEBASTIÃO - GUAECÁ
# GUARUJÁ - TOMBO
# SÃO SEBASTIÃO - BOIÇUCANGA
# PRAIA GRANDE - BALNEÁRIO FLÓRIDA
# GUARUJÁ - ASTÚRIAS
# BERTIOGA - SÃO LOURENÇO (JUNTO AO MORRO)
# SANTOS - APARECIDA
# CARAGUATATUBA - TABATINGA (CONDOM. GAIVOTAS)
# GUARUJÁ - PITANGUEIRAS (R. SILVIA VALADÃO)
# SÃO SEBASTIÃO - PORTO GRANDE
# UBATUBA - TONINHAS
# SÃO SEBASTIÃO - BORACÉIA - R. CUBATÃO
# GUARUJÁ - ENSEADA (AV. SANTA MARIA)
# PRAIA GRANDE - BOQUEIRÃO
# ILHABELA - JULIÃO
# ILHA COMPRIDA - BALNEÁRIO ADRIANA
# ILHABELA - BARREIROS SUL
# ILHABELA - BARREIROS NORTE
# ILHABELA - ENGENHO D'ÁGUA
# ITANHAÉM - JARDIM REGINA
# GUARUJÁ - IPORANGA
# ITANHAÉM - SUARÃO - AFPESP
# MONGAGUÁ - FLÓRIDA MIRIM
# ILHABELA - VELOSO
# SÃO SEBASTIÃO - MARESIAS - TOTEM

# %%
df_aux=df.pivot(index='praia', columns='Date', values='Enterococcus' )
df_aux.fillna(df_aux.mean(), inplace=True)
df_aux=df_aux.astype('int32')
df_aux
#d = {'praia': [praia]}
#df_novo = pd.DataFrame(data=d) 
#pd.concat([df_novo, df_aux['Enterococcus']], axis=1)
#df_novo = df_novo.join(df_aux['Enterococcus'].T)
#df_novo
# Out:
# Date                                      2012-01-03  2012-01-08  2012-01-15  \
# praia
# BERTIOGA - BORACÉIA - COL. MARISTA                 8          22          17
# BERTIOGA - BORACÉIA - SUL                         16           1           1
# BERTIOGA - ENSEADA - COLÔNIA DO SESC             128          42          18
# BERTIOGA - ENSEADA - INDAIÁ                       17          85           1
# BERTIOGA - ENSEADA - R. RAFAEL COSTABILI         204          34          19
# ...                                              ...         ...         ...
# UBATUBA - SUNUNGA                                  5           6          34
# UBATUBA - TENÓRIO                                  9          96          42
# UBATUBA - TONINHAS                                 1         128          21
# UBATUBA - VERMELHA                                 1           5          61
# UBATUBA - VERMELHA DO NORTE                        1           7           1
#
# Date                                      2012-01-22  2012-01-29  2012-02-05  \
# praia
# BERTIOGA - BORACÉIA - COL. MARISTA                 8           2           1
# BERTIOGA - BORACÉIA - SUL                         15           7           2
# BERTIOGA - ENSEADA - COLÔNIA DO SESC              31          11          19
# BERTIOGA - ENSEADA - INDAIÁ                       10         108           6
# BERTIOGA - ENSEADA - R. RAFAEL COSTABILI          33          10          25
# ...                                              ...         ...         ...
# UBATUBA - SUNUNGA                                  9           3           5
# UBATUBA - TENÓRIO                                 14           7          17
# UBATUBA - TONINHAS                                11          13           2
# UBATUBA - VERMELHA                                 1           7           3
# UBATUBA - VERMELHA DO NORTE                        1           1           1
#
# Date                                      2012-02-12  2012-02-19  2012-02-26  \
# praia
# BERTIOGA - BORACÉIA - COL. MARISTA                68          32           1
# BERTIOGA - BORACÉIA - SUL                         18          45           4
# BERTIOGA - ENSEADA - COLÔNIA DO SESC             252          36           1
# BERTIOGA - ENSEADA - INDAIÁ                        7          29          15
# BERTIOGA - ENSEADA - R. RAFAEL COSTABILI         288          57          42
# ...                                              ...         ...         ...
# UBATUBA - SUNUNGA                                  9           2           3
# UBATUBA - TENÓRIO                                  5           1          12
# UBATUBA - TONINHAS                                13          21          28
# UBATUBA - VERMELHA                                 5           1           2
# UBATUBA - VERMELHA DO NORTE                        1          12           6
#
# Date                                      2012-03-04  ...  2020-07-27  \
# praia                                                 ...
# BERTIOGA - BORACÉIA - COL. MARISTA                 1  ...          15
# BERTIOGA - BORACÉIA - SUL                          1  ...          15
# BERTIOGA - ENSEADA - COLÔNIA DO SESC               2  ...          15
# BERTIOGA - ENSEADA - INDAIÁ                        1  ...          15
# BERTIOGA - ENSEADA - R. RAFAEL COSTABILI           2  ...           3
# ...                                              ...  ...         ...
# UBATUBA - SUNUNGA                                  1  ...          15
# UBATUBA - TENÓRIO                                  5  ...           9
# UBATUBA - TONINHAS                                 2  ...          36
# UBATUBA - VERMELHA                                 9  ...          15
# UBATUBA - VERMELHA DO NORTE                        6  ...          15
#
# Date                                      2020-08-03  2020-08-10  2020-08-17  \
# praia
# BERTIOGA - BORACÉIA - COL. MARISTA                20          18          48
# BERTIOGA - BORACÉIA - SUL                         20          18          48
# BERTIOGA - ENSEADA - COLÔNIA DO SESC              20          18          48
# BERTIOGA - ENSEADA - INDAIÁ                       20          18          48
# BERTIOGA - ENSEADA - R. RAFAEL COSTABILI          43           3          30
# ...                                              ...         ...         ...
# UBATUBA - SUNUNGA                                 20          18          48
# UBATUBA - TENÓRIO                                  1           3          14
# UBATUBA - TONINHAS                                 9           3           7
# UBATUBA - VERMELHA                                20          18          48
# UBATUBA - VERMELHA DO NORTE                       20          18          48
#
# Date                                      2020-08-24  2020-08-31  2020-09-07  \
# praia
# BERTIOGA - BORACÉIA - COL. MARISTA                33          35          39
# BERTIOGA - BORACÉIA - SUL                         33          35          39
# BERTIOGA - ENSEADA - COLÔNIA DO SESC              33          35          39
# BERTIOGA - ENSEADA - INDAIÁ                       33          35          39
# BERTIOGA - ENSEADA - R. RAFAEL COSTABILI          30           8           2
# ...                                              ...         ...         ...
# UBATUBA - SUNUNGA                                 33          35          39
# UBATUBA - TENÓRIO                                  2           1          12
# UBATUBA - TONINHAS                                 9          18          10
# UBATUBA - VERMELHA                                33          35          39
# UBATUBA - VERMELHA DO NORTE                       33          35          39
#
# Date                                      2020-09-14  2020-09-21  2020-09-28
# praia
# BERTIOGA - BORACÉIA - COL. MARISTA                36         287          91
# BERTIOGA - BORACÉIA - SUL                         36         287          91
# BERTIOGA - ENSEADA - COLÔNIA DO SESC              36         287          91
# BERTIOGA - ENSEADA - INDAIÁ                       36         287          91
# BERTIOGA - ENSEADA - R. RAFAEL COSTABILI           2         152          61
# ...                                              ...         ...         ...
# UBATUBA - SUNUNGA                                 36         287          91
# UBATUBA - TENÓRIO                                  1          86           4
# UBATUBA - TONINHAS                                 2         188          41
# UBATUBA - VERMELHA                                36         287          91
# UBATUBA - VERMELHA DO NORTE                       36         287          91
#
# [174 rows x 429 columns]

# %%
def train_test_split(data, train_portion):
    time_len = data.shape[1]
    train_size = int(time_len * train_portion)
    train_data = np.array(data.iloc[:, :train_size])
    test_data = np.array(data.iloc[:, train_size:])
    return train_data, test_data

# %%
train_rate = 0.9
train_data, test_data = train_test_split(df_aux, train_rate)
print("Train data: ", train_data.shape)
print("Test data: ", test_data.shape)
# Out:
# Train data:  (174, 386)
# Test data:  (174, 43)

# %%
def scale_data(train_data, test_data):
    max_speed = train_data.max()
    min_speed = train_data.min()
    train_scaled = (train_data - min_speed) / (max_speed - min_speed)
    test_scaled = (test_data - min_speed) / (max_speed - min_speed)
    return train_scaled, test_scaled

# %%
train_scaled, test_scaled = scale_data(train_data, test_data)
print("Train data: ", train_scaled.shape)
print("Test data: ", test_scaled.shape)
# Out:
# Train data:  (174, 386)
# Test data:  (174, 43)

# %%
seq_len = 12
pre_len = 10

# %%
def sequence_data_preparation(seq_len, pre_len, train_data, test_data):
    trainX, trainY, testX, testY = [], [], [], []

    for i in range(train_data.shape[1] - int(seq_len + pre_len - 1)):
        a = train_data[:, i : i + seq_len + pre_len]
        trainX.append(a[:, :seq_len])
        trainY.append(a[:, -1])

    for i in range(test_data.shape[1] - int(seq_len + pre_len - 1)):
        b = test_data[:, i : i + seq_len + pre_len]
        testX.append(b[:, :seq_len])
        testY.append(b[:, -1])

    trainX = np.array(trainX)
    trainY = np.array(trainY)
    testX = np.array(testX)
    testY = np.array(testY)

    return trainX, trainY, testX, testY

# %%
trainX, trainY, testX, testY = sequence_data_preparation(
    seq_len, pre_len, train_scaled, test_scaled
)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (365, 174, 12)
# (365, 174)
# (22, 174, 12)
# (22, 174)

# %%
adj_praias = np.zeros((174,174))

# %%
gcn_lstm = GCN_LSTM(
    seq_len=seq_len,
    adj=adj_praias,
    gc_layer_sizes=[16, 10],
    gc_activations=["relu", "relu"],
    lstm_layer_sizes=[200, 200],
    lstm_activations=["tanh", "tanh"],
)
# Out:
# C:\Users\User\anaconda3\envs\StellarGraph-gpu\lib\site-packages\ipykernel_launcher.py:7: ExperimentalWarning: GCN_LSTM is experimental: Lack of unit tests and code refinement (see: https://github.com/stellargraph/stellargraph/issues/1132, https://github.com/stellargraph/stellargraph/issues/1526, https://github.com/stellargraph/stellargraph/issues/1564). It may be difficult to use and may have major changes at any time.
#   import sys
# C:\Users\User\anaconda3\envs\StellarGraph-gpu\lib\site-packages\stellargraph\core\utils.py:157: RuntimeWarning: divide by zero encountered in power
#   D = np.diag(np.ravel(adj.sum(axis=0)) ** (-0.5))

# %%
x_input, x_output = gcn_lstm.in_out_tensors()
model = Model(inputs=x_input, outputs=x_output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 174, 12)]         0
# _________________________________________________________________
# tf_op_layer_ExpandDims (Tens [(None, 174, 12, 1)]      0
# _________________________________________________________________
# reshape (Reshape)            (None, 174, 12)           0
# _________________________________________________________________
# fixed_adjacency_graph_convol (None, 174, 16)           30642
# _________________________________________________________________
# fixed_adjacency_graph_convol (None, 174, 10)           30610
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 174, None, 1)      0
# _________________________________________________________________
# permute (Permute)            (None, None, 174, 1)      0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, None, 174)         0
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 200)         300000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 200)               320800
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 174)               34974
# =================================================================
# Total params: 717,026
# Trainable params: 656,474
# Non-trainable params: 60,552
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mae", metrics=["mse"])

# %%
with tf.device('/GPU:0'): 
    history = model.fit(
        trainX,
        trainY,
        epochs=100,
        batch_size=60,
        shuffle=True,
        verbose=1,
        validation_data=[testX, testY],
    )
history

# %%
print(
    "Train loss: ",
    history.history["loss"][-1],
    "\nTest loss:",
    history.history["val_loss"][-1],
)
# Out:
# Train loss:  0.010714909942080714
# Test loss: 0.013232824392616749

# %%
sg.utils.plot_history(history)

# %%
ythat = model.predict(trainX)
yhat = model.predict(testX)
print(ythat.shape)
print(yhat.shape)
# Out:
# (365, 174)
# (22, 174)

# %%
## Rescale values
max_esterococos = train_data.max()
min_esterococos = train_data.min()

## actual train and test values
train_rescref = np.array(trainY * max_esterococos)
test_rescref = np.array(testY * max_esterococos)

# %%
train_rescpred = np.array((ythat) * max_esterococos)
test_rescpred = np.array((yhat) * max_esterococos)

# %%
testnpred = np.array(testX)[
    :, :, -1
]  # picking the last speed of the 10 sequence for each segment in each sample
testnpredc = (testnpred) * max_speed

# %%
## Performance measures

seg_mael = []
seg_masel = []
seg_nmael = []

for j in range(testX.shape[-1]):

    seg_mael.append(
        np.mean(np.abs(test_rescref.T[j] - test_rescpred.T[j]))
    )  # Mean Absolute Error for NN
    seg_nmael.append(
        np.mean(np.abs(test_rescref.T[j] - testnpredc.T[j]))
    )  # Mean Absolute Error for naive prediction
    if seg_nmael[-1] != 0:
        seg_masel.append(
            seg_mael[-1] / seg_nmael[-1]
        )  # Ratio of the two: Mean Absolute Scaled Error
    else:
        seg_masel.append(np.NaN)

print("Total (ave) MAE for NN: " + str(np.mean(np.array(seg_mael))))
print("Total (ave) MAE for naive prediction: " + str(np.mean(np.array(seg_nmael))))
print(
    "Total (ave) MASE for per-segment NN/naive MAE: "
    + str(np.nanmean(np.array(seg_masel)))
)
print(
    "...note that MASE<1 (for a given segment) means that the NN prediction is better than the naive prediction."
)
# Out:
# Total (ave) MAE for NN: 43.01128145862549
# Total (ave) MAE for naive prediction: 49.94938381615717
# Total (ave) MASE for per-segment NN/naive MAE: 0.9252919640111353
# ...note that MASE<1 (for a given segment) means that the NN prediction is better than the naive prediction.

# %%
# plot violin plot of MAE for naive and NN predictions
fig, ax = plt.subplots()
# xl = minsl

ax.violinplot(
    list(seg_mael), showmeans=True, showmedians=False, showextrema=False, widths=1.0
)

ax.violinplot(
    list(seg_nmael), showmeans=True, showmedians=False, showextrema=False, widths=1.0
)

line1 = mlines.Line2D([], [], label="NN")
line2 = mlines.Line2D([], [], color="C1", label="Instantaneous")

ax.set_xlabel("Scaled distribution amplitude (after Gaussian convolution)")
ax.set_ylabel("Mean Absolute Error")
ax.set_title("Distribution over segments: NN pred (blue) and naive pred (orange)")
plt.legend(handles=(line1, line2), title="Prediction Model", loc=2)
plt.show()

# %%
##all test result visualization
fig1 = plt.figure(figsize=(15, 8))
#    ax1 = fig1.add_subplot(1,1,1)
a_pred = test_rescpred[:, 100]
a_true = test_rescref[:, 100]
plt.plot(a_pred, "r-", label="prediction")
plt.plot(a_true, "b-", label="true")
plt.xlabel("time")
plt.ylabel("speed")
plt.legend(loc="best", fontsize=10)
plt.show()
