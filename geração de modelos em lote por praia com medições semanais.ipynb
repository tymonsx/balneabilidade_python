# %%
from numpy import array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
import numpy as np
import pandas as pd
import tensorflow as tf
print(tf.__version__)
print(np.__version__)
# Out:
# 2.3.0
# 1.18.5

# %%
# divide uma série temporal univariada em amostras
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # encontra o final da amostra
        end_ix = i + n_steps
        # verifica se passou do final
        if end_ix > len(sequence)-1:
            break
        # junta as partes de entrada e saída do padrão
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
df = pd.read_csv('sp_beaches_update.csv', parse_dates=['Date'])
df = df.sort_values(by=['Date'])
df=df.loc[~df['Enterococcus'].isnull()]
#remover a praia do Leste, da cidade de iguape, pois esta praia sumiu por erosão em 2012
#remover a praia MASSAGUAÇU (AV. M. H. CARVALHO), da cidade de CARAGUATATUBA, não possui mais medições em 2021
#remover a praia RIO PEREQUÊ, da cidade de CUBATÃO, até dez de 2020 possuía medições semanais, depois de janeiro de 2021 as medições passaram a ser mensais
#remover as praias da cidade ILHA ANCHIETA pois não exitem mais medições em 2021
df = df.loc[df['Beach']!='DO LESTE'].loc[df['Beach']!='MASSAGUAÇU (AV. M. H. CARVALHO)'].loc[df['Beach']!='RIO PEREQUÊ'].loc[df['City']!='ILHA ANCHIETA']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71443 entries, 0 to 70616
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          71443 non-null  object
#  1   Beach         71443 non-null  object
#  2   Date          71443 non-null  datetime64[ns]
#  3   Enterococcus  71443 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 2.7+ MB

# %%
df.loc[df['City']=='UBATUBA'].loc[df['Beach']=='GRANDE']
# Out:
#           City   Beach       Date  Enterococcus
# 7614   UBATUBA  GRANDE 2012-01-03             5
# 7615   UBATUBA  GRANDE 2012-01-08            42
# 7616   UBATUBA  GRANDE 2012-01-15            92
# 7617   UBATUBA  GRANDE 2012-01-22            16
# 7618   UBATUBA  GRANDE 2012-01-29             9
# ...        ...     ...        ...           ...
# 74360  UBATUBA  GRANDE 2021-07-19            38
# 74361  UBATUBA  GRANDE 2021-07-26            17
# 74362  UBATUBA  GRANDE 2021-08-02             1
# 74363  UBATUBA  GRANDE 2021-08-09             1
# 74364  UBATUBA  GRANDE 2021-08-16             1
#
# [469 rows x 4 columns]

# %%
# selecionar praias com medições semanal
df_freq = pd.read_csv('frequencia_praias.csv')
df_freq = df_freq.loc[df_freq['Beach']!='DO LESTE'].loc[df_freq['Beach']!='MASSAGUAÇU (AV. M. H. CARVALHO)'].loc[df_freq['Beach']!='RIO PEREQUÊ'].loc[df_freq['City']!='ILHA ANCHIETA']
df_freq = df_freq.loc[df_freq['Frequency']=='SEMANAL']
df_freq
# Out:
#          City                          Beach Frequency
# 11   BERTIOGA        BORACÉIA - COL. MARISTA   SEMANAL
# 12   BERTIOGA                 BORACÉIA - SUL   SEMANAL
# 13   BERTIOGA                      GUARATUBA   SEMANAL
# 14   BERTIOGA  SÃO LOURENÇO (JUNTO AO MORRO)   SEMANAL
# 15   BERTIOGA           SÃO LOURENÇO (RUA 2)   SEMANAL
# ..        ...                            ...       ...
# 161   UBATUBA                           DURA   SEMANAL
# 162   UBATUBA    LAGOINHA (R. ENGENHO VELHO)   SEMANAL
# 163   UBATUBA             LAGOINHA (CAMPING)   SEMANAL
# 164   UBATUBA                           SAPÉ   SEMANAL
# 165   UBATUBA                      MARANDUBA   SEMANAL
#
# [155 rows x 3 columns]

# %%
n_steps = 16 #16 medições representa 4 meses que serão utilizados para prever a próxima medição
#Para cada cidade 
for cidade in df_freq.City.unique():
    # Para cada praia desta cidade
    for praia in df_freq.loc[df_freq['City']==cidade].Beach.unique():
        #Imprime que iniicou o processo de carregamento de dados de uma determinada praia
        print(f'iniciando: {cidade} - {praia}')
        #Coleta os dados desta praia
        df_beach = df.loc[df['City']==cidade].loc[df['Beach']==praia][['Date','Enterococcus']]
        #formata os dados desta praia para enviar ao modelo
        df_beach.columns = ['ds', 'y']
        df_beach.set_index('ds', inplace=True)
        #divide os dados da praia em lotes de X com n_steps medições para y com 1 medição de rótulo
        X, y = split_sequence(df_beach.values, n_steps)
        #formata de acordo com a entrada do modelo
        n_features = 1
        X = X.reshape((X.shape[0], X.shape[1], n_features))
        #prepara as camadas do modelo
        model = Sequential()
        model.add(LSTM(104, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
        model.add(LSTM(104, activation='relu'))
        model.add(Dense(1))
        model.compile(optimizer='adam', loss='mse')
        #imprime que o modelo irá começar a ser treinado para esta praia
        print('Treinando modelo: '+cidade+'-'+praia)
        #começa o treino do modelo na GPU
        with tf.device('/GPU:0'): 
            R = model.fit(X, y, epochs=200, verbose=0)
        #depois de treinado pega o erro do MSE
        loss=round(R.history['loss'][-1])
        #salva o modelo com o nome de modelcidade-praia.h5
        model.save('model'+cidade+'-'+praia+'.h5')
        #imprime que o modelo foi treinado e o valor do erro MSE
        print('Modelo Treinado: '+cidade+'-'+praia+'- MSE:'+str(loss))
# Out:
# iniciando: BERTIOGA - BORACÉIA - COL. MARISTA
# Treinando modelo: BERTIOGA-BORACÉIA - COL. MARISTA
# Modelo Treinado: BERTIOGA-BORACÉIA - COL. MARISTA- MSE:1781
# iniciando: BERTIOGA - BORACÉIA - SUL
# Treinando modelo: BERTIOGA-BORACÉIA - SUL
# Modelo Treinado: BERTIOGA-BORACÉIA - SUL- MSE:1538
# iniciando: BERTIOGA - GUARATUBA
# Treinando modelo: BERTIOGA-GUARATUBA
# Modelo Treinado: BERTIOGA-GUARATUBA- MSE:146
# iniciando: BERTIOGA - SÃO LOURENÇO (JUNTO AO MORRO)
# Treinando modelo: BERTIOGA-SÃO LOURENÇO (JUNTO AO MORRO)
# Modelo Treinado: BERTIOGA-SÃO LOURENÇO (JUNTO AO MORRO)- MSE:776
# iniciando: BERTIOGA - SÃO LOURENÇO (RUA 2)
# Treinando modelo: BERTIOGA-SÃO LOURENÇO (RUA 2)
# Modelo Treinado: BERTIOGA-SÃO LOURENÇO (RUA 2)- MSE:1078
# iniciando: BERTIOGA - ENSEADA - INDAIÁ
# Treinando modelo: BERTIOGA-ENSEADA - INDAIÁ
# Modelo Treinado: BERTIOGA-ENSEADA - INDAIÁ- MSE:2442
# iniciando: BERTIOGA - ENSEADA - VISTA LINDA
# Treinando modelo: BERTIOGA-ENSEADA - VISTA LINDA
# Modelo Treinado: BERTIOGA-ENSEADA - VISTA LINDA- MSE:1635
# iniciando: BERTIOGA - ENSEADA - COLÔNIA DO SESC
# Treinando modelo: BERTIOGA-ENSEADA - COLÔNIA DO SESC
# Modelo Treinado: BERTIOGA-ENSEADA - COLÔNIA DO SESC- MSE:4498
# iniciando: BERTIOGA - ENSEADA - R. RAFAEL COSTABILI
# Treinando modelo: BERTIOGA-ENSEADA - R. RAFAEL COSTABILI
# Modelo Treinado: BERTIOGA-ENSEADA - R. RAFAEL COSTABILI- MSE:4125
# iniciando: CARAGUATATUBA - TABATINGA (250M RIO TABATINGA)
# Treinando modelo: CARAGUATATUBA-TABATINGA (250M RIO TABATINGA)
# Modelo Treinado: CARAGUATATUBA-TABATINGA (250M RIO TABATINGA)- MSE:11541
# iniciando: CARAGUATATUBA - TABATINGA (CONDOM. GAIVOTAS)
# Treinando modelo: CARAGUATATUBA-TABATINGA (CONDOM. GAIVOTAS)
# Modelo Treinado: CARAGUATATUBA-TABATINGA (CONDOM. GAIVOTAS)- MSE:55
# iniciando: CARAGUATATUBA - MOCOÓCA
# Treinando modelo: CARAGUATATUBA-MOCOÓCA
# Modelo Treinado: CARAGUATATUBA-MOCOÓCA- MSE:981
# iniciando: CARAGUATATUBA - COCANHA
# Treinando modelo: CARAGUATATUBA-COCANHA
# Modelo Treinado: CARAGUATATUBA-COCANHA- MSE:3551
# iniciando: CARAGUATATUBA - MASSAGUAÇU (R. MARIA CARLOTA)
# Treinando modelo: CARAGUATATUBA-MASSAGUAÇU (R. MARIA CARLOTA)
# Modelo Treinado: CARAGUATATUBA-MASSAGUAÇU (R. MARIA CARLOTA)- MSE:1993
# iniciando: CARAGUATATUBA - CAPRICÓRNIO
# Treinando modelo: CARAGUATATUBA-CAPRICÓRNIO
# Modelo Treinado: CARAGUATATUBA-CAPRICÓRNIO- MSE:1
# iniciando: CARAGUATATUBA - MARTIM DE SÁ
# Treinando modelo: CARAGUATATUBA-MARTIM DE SÁ
# Modelo Treinado: CARAGUATATUBA-MARTIM DE SÁ- MSE:6359
# iniciando: CARAGUATATUBA - PRAINHA
# Treinando modelo: CARAGUATATUBA-PRAINHA
# Modelo Treinado: CARAGUATATUBA-PRAINHA- MSE:10265
# iniciando: CARAGUATATUBA - CENTRO
# Treinando modelo: CARAGUATATUBA-CENTRO
# Modelo Treinado: CARAGUATATUBA-CENTRO- MSE:17482
# iniciando: CARAGUATATUBA - INDAIÁ
# Treinando modelo: CARAGUATATUBA-INDAIÁ
# Modelo Treinado: CARAGUATATUBA-INDAIÁ- MSE:30746
# iniciando: CARAGUATATUBA - PAN BRASIL
# Treinando modelo: CARAGUATATUBA-PAN BRASIL
# Modelo Treinado: CARAGUATATUBA-PAN BRASIL- MSE:6650
# iniciando: CARAGUATATUBA - PALMEIRAS
# Treinando modelo: CARAGUATATUBA-PALMEIRAS
# Modelo Treinado: CARAGUATATUBA-PALMEIRAS- MSE:14307
# iniciando: CARAGUATATUBA - PORTO NOVO
# Treinando modelo: CARAGUATATUBA-PORTO NOVO
# Modelo Treinado: CARAGUATATUBA-PORTO NOVO- MSE:25736
# iniciando: GUARUJÁ - PEREQUÊ
# Treinando modelo: GUARUJÁ-PEREQUÊ
# Modelo Treinado: GUARUJÁ-PEREQUÊ- MSE:381993
# iniciando: GUARUJÁ - PERNAMBUCO
# Treinando modelo: GUARUJÁ-PERNAMBUCO
# Modelo Treinado: GUARUJÁ-PERNAMBUCO- MSE:4775
# iniciando: GUARUJÁ - ENSEADA (ESTR. DE PERNAMBUCO)
# Treinando modelo: GUARUJÁ-ENSEADA (ESTR. DE PERNAMBUCO)
# Modelo Treinado: GUARUJÁ-ENSEADA (ESTR. DE PERNAMBUCO)- MSE:11906
# iniciando: GUARUJÁ - ENSEADA (AV. ATLÂNTICA)
# Treinando modelo: GUARUJÁ-ENSEADA (AV. ATLÂNTICA)
# Modelo Treinado: GUARUJÁ-ENSEADA (AV. ATLÂNTICA)- MSE:6302
# iniciando: GUARUJÁ - ENSEADA (R. CHILE)
# Treinando modelo: GUARUJÁ-ENSEADA (R. CHILE)
# Modelo Treinado: GUARUJÁ-ENSEADA (R. CHILE)- MSE:7855
# iniciando: GUARUJÁ - ENSEADA (AV. SANTA MARIA)
# Treinando modelo: GUARUJÁ-ENSEADA (AV. SANTA MARIA)
# Modelo Treinado: GUARUJÁ-ENSEADA (AV. SANTA MARIA)- MSE:8183
# iniciando: GUARUJÁ - PITANGUEIRAS (AV. PUGLISI)
# Treinando modelo: GUARUJÁ-PITANGUEIRAS (AV. PUGLISI)
# Modelo Treinado: GUARUJÁ-PITANGUEIRAS (AV. PUGLISI)- MSE:7
# iniciando: GUARUJÁ - PITANGUEIRAS (R. SILVIA VALADÃO)
# Treinando modelo: GUARUJÁ-PITANGUEIRAS (R. SILVIA VALADÃO)
# Modelo Treinado: GUARUJÁ-PITANGUEIRAS (R. SILVIA VALADÃO)- MSE:5523
# iniciando: GUARUJÁ - ASTÚRIAS
# Treinando modelo: GUARUJÁ-ASTÚRIAS
# Modelo Treinado: GUARUJÁ-ASTÚRIAS- MSE:3960
# iniciando: GUARUJÁ - TOMBO
# Treinando modelo: GUARUJÁ-TOMBO
# Modelo Treinado: GUARUJÁ-TOMBO- MSE:1021
# iniciando: GUARUJÁ - GUAIÚBA
# Treinando modelo: GUARUJÁ-GUAIÚBA
# Modelo Treinado: GUARUJÁ-GUAIÚBA- MSE:3503
# iniciando: ILHABELA - ARMAÇÃO
# Treinando modelo: ILHABELA-ARMAÇÃO
# Modelo Treinado: ILHABELA-ARMAÇÃO- MSE:21014
# iniciando: ILHABELA - PINTO
# Treinando modelo: ILHABELA-PINTO
# Modelo Treinado: ILHABELA-PINTO- MSE:16673
# iniciando: ILHABELA - SINO
# Treinando modelo: ILHABELA-SINO
# Modelo Treinado: ILHABELA-SINO- MSE:13315
# iniciando: ILHABELA - SIRIÚBA
# Treinando modelo: ILHABELA-SIRIÚBA
# Modelo Treinado: ILHABELA-SIRIÚBA- MSE:6100
# iniciando: ILHABELA - VIANA
# Treinando modelo: ILHABELA-VIANA
# Modelo Treinado: ILHABELA-VIANA- MSE:15976
# iniciando: ILHABELA - BARREIROS NORTE
# Treinando modelo: ILHABELA-BARREIROS NORTE
# Modelo Treinado: ILHABELA-BARREIROS NORTE- MSE:13998
# iniciando: ILHABELA - BARREIROS SUL
# Treinando modelo: ILHABELA-BARREIROS SUL
# Modelo Treinado: ILHABELA-BARREIROS SUL- MSE:7160
# iniciando: ILHABELA - SACO DA CAPELA
# Treinando modelo: ILHABELA-SACO DA CAPELA
# Modelo Treinado: ILHABELA-SACO DA CAPELA- MSE:11445
# iniciando: ILHABELA - ENGENHO D'ÁGUA
# Treinando modelo: ILHABELA-ENGENHO D'ÁGUA
# Modelo Treinado: ILHABELA-ENGENHO D'ÁGUA- MSE:11796
# iniciando: ILHABELA - ITAQUANDUBA
# Treinando modelo: ILHABELA-ITAQUANDUBA
# Modelo Treinado: ILHABELA-ITAQUANDUBA- MSE:75178
# iniciando: ILHABELA - ITAGUAÇU
# Treinando modelo: ILHABELA-ITAGUAÇU
# Modelo Treinado: ILHABELA-ITAGUAÇU- MSE:30909
# iniciando: ILHABELA - PEREQUÊ
# Treinando modelo: ILHABELA-PEREQUÊ
# Modelo Treinado: ILHABELA-PEREQUÊ- MSE:21738
# iniciando: ILHABELA - ILHA DAS CABRAS
# Treinando modelo: ILHABELA-ILHA DAS CABRAS
# Modelo Treinado: ILHABELA-ILHA DAS CABRAS- MSE:8629
# iniciando: ILHABELA - PORTINHO
# Treinando modelo: ILHABELA-PORTINHO
# Modelo Treinado: ILHABELA-PORTINHO- MSE:19007
# iniciando: ILHABELA - FEITICEIRA
# Treinando modelo: ILHABELA-FEITICEIRA
# Modelo Treinado: ILHABELA-FEITICEIRA- MSE:15519
# iniciando: ILHABELA - JULIÃO
# Treinando modelo: ILHABELA-JULIÃO
# Modelo Treinado: ILHABELA-JULIÃO- MSE:7189
# iniciando: ILHABELA - GRANDE
# Treinando modelo: ILHABELA-GRANDE
# Modelo Treinado: ILHABELA-GRANDE- MSE:3516
# iniciando: ILHABELA - CURRAL
# Treinando modelo: ILHABELA-CURRAL
# Modelo Treinado: ILHABELA-CURRAL- MSE:2776
# iniciando: ITANHAÉM - CAMPOS ELÍSEOS
# Treinando modelo: ITANHAÉM-CAMPOS ELÍSEOS
# Modelo Treinado: ITANHAÉM-CAMPOS ELÍSEOS- MSE:11282
# iniciando: ITANHAÉM - SUARÃO
# Treinando modelo: ITANHAÉM-SUARÃO
# Modelo Treinado: ITANHAÉM-SUARÃO- MSE:11107
# iniciando: ITANHAÉM - SUARÃO - AFPESP
# Treinando modelo: ITANHAÉM-SUARÃO - AFPESP
# Modelo Treinado: ITANHAÉM-SUARÃO - AFPESP- MSE:6238
# iniciando: ITANHAÉM - PARQUE BALNEÁRIO
# Treinando modelo: ITANHAÉM-PARQUE BALNEÁRIO
# Modelo Treinado: ITANHAÉM-PARQUE BALNEÁRIO- MSE:9060
# iniciando: ITANHAÉM - CENTRO
# Treinando modelo: ITANHAÉM-CENTRO
# Modelo Treinado: ITANHAÉM-CENTRO- MSE:10364
# iniciando: ITANHAÉM - PRAIA DOS PESCADORES
# Treinando modelo: ITANHAÉM-PRAIA DOS PESCADORES
# Modelo Treinado: ITANHAÉM-PRAIA DOS PESCADORES- MSE:8064
# iniciando: ITANHAÉM - SONHO
# Treinando modelo: ITANHAÉM-SONHO
# Modelo Treinado: ITANHAÉM-SONHO- MSE:5392
# iniciando: ITANHAÉM - JARDIM CIBRATEL
# Treinando modelo: ITANHAÉM-JARDIM CIBRATEL
# Modelo Treinado: ITANHAÉM-JARDIM CIBRATEL- MSE:9132
# iniciando: ITANHAÉM - ESTÂNCIA BALNEÁRIA
# Treinando modelo: ITANHAÉM-ESTÂNCIA BALNEÁRIA
# Modelo Treinado: ITANHAÉM-ESTÂNCIA BALNEÁRIA- MSE:5226
# iniciando: ITANHAÉM - JARDIM SÃO FERNANDO
# Treinando modelo: ITANHAÉM-JARDIM SÃO FERNANDO
# Modelo Treinado: ITANHAÉM-JARDIM SÃO FERNANDO- MSE:3453
# iniciando: ITANHAÉM - JARDIM REGINA
# Treinando modelo: ITANHAÉM-JARDIM REGINA
# Modelo Treinado: ITANHAÉM-JARDIM REGINA- MSE:4949
# iniciando: ITANHAÉM - BALNEÁRIO GAIVOTA
# Treinando modelo: ITANHAÉM-BALNEÁRIO GAIVOTA
# Modelo Treinado: ITANHAÉM-BALNEÁRIO GAIVOTA- MSE:11136
# iniciando: MONGAGUÁ - ITAPOÃ - VILA SÃO PAULO
# Treinando modelo: MONGAGUÁ-ITAPOÃ - VILA SÃO PAULO
# Modelo Treinado: MONGAGUÁ-ITAPOÃ - VILA SÃO PAULO- MSE:14862
# iniciando: MONGAGUÁ - CENTRAL
# Treinando modelo: MONGAGUÁ-CENTRAL
# Modelo Treinado: MONGAGUÁ-CENTRAL- MSE:16315
# iniciando: MONGAGUÁ - VERA CRUZ
# Treinando modelo: MONGAGUÁ-VERA CRUZ
# Modelo Treinado: MONGAGUÁ-VERA CRUZ- MSE:17635
# iniciando: MONGAGUÁ - SANTA EUGÊNIA
# Treinando modelo: MONGAGUÁ-SANTA EUGÊNIA
# Modelo Treinado: MONGAGUÁ-SANTA EUGÊNIA- MSE:16945
# iniciando: MONGAGUÁ - ITAÓCA
# Treinando modelo: MONGAGUÁ-ITAÓCA
# Modelo Treinado: MONGAGUÁ-ITAÓCA- MSE:15098
# iniciando: MONGAGUÁ - AGENOR DE CAMPOS
# Treinando modelo: MONGAGUÁ-AGENOR DE CAMPOS
# Modelo Treinado: MONGAGUÁ-AGENOR DE CAMPOS- MSE:11826
# iniciando: MONGAGUÁ - FLÓRIDA MIRIM
# Treinando modelo: MONGAGUÁ-FLÓRIDA MIRIM
# Modelo Treinado: MONGAGUÁ-FLÓRIDA MIRIM- MSE:10767
# iniciando: PERUÍBE - PERUÍBE (R. ICARAÍBA)
# Treinando modelo: PERUÍBE-PERUÍBE (R. ICARAÍBA)
# Modelo Treinado: PERUÍBE-PERUÍBE (R. ICARAÍBA)- MSE:8010
# iniciando: PERUÍBE - PERUÍBE (PARQUE TURÍSTICO)
# Treinando modelo: PERUÍBE-PERUÍBE (PARQUE TURÍSTICO)
# Modelo Treinado: PERUÍBE-PERUÍBE (PARQUE TURÍSTICO)- MSE:12555
# iniciando: PERUÍBE - PERUÍBE (BALN. SÃO JOÃO BATISTA)
# Treinando modelo: PERUÍBE-PERUÍBE (BALN. SÃO JOÃO BATISTA)
# Modelo Treinado: PERUÍBE-PERUÍBE (BALN. SÃO JOÃO BATISTA)- MSE:13546
# iniciando: PERUÍBE - PERUÍBE (AV. S. JOÃO)
# Treinando modelo: PERUÍBE-PERUÍBE (AV. S. JOÃO)
# Modelo Treinado: PERUÍBE-PERUÍBE (AV. S. JOÃO)- MSE:11536
# iniciando: PERUÍBE - PRAINHA
# Treinando modelo: PERUÍBE-PRAINHA
# Modelo Treinado: PERUÍBE-PRAINHA- MSE:12564
# iniciando: PERUÍBE - GUARAÚ
# Treinando modelo: PERUÍBE-GUARAÚ
# Modelo Treinado: PERUÍBE-GUARAÚ- MSE:6866
# iniciando: PRAIA GRANDE - CANTO DO FORTE
# Treinando modelo: PRAIA GRANDE-CANTO DO FORTE
# Modelo Treinado: PRAIA GRANDE-CANTO DO FORTE- MSE:22135
# iniciando: PRAIA GRANDE - BOQUEIRÃO
# Treinando modelo: PRAIA GRANDE-BOQUEIRÃO
# Modelo Treinado: PRAIA GRANDE-BOQUEIRÃO- MSE:23547
# iniciando: PRAIA GRANDE - GUILHERMINA
# Treinando modelo: PRAIA GRANDE-GUILHERMINA
# Modelo Treinado: PRAIA GRANDE-GUILHERMINA- MSE:25070
# iniciando: PRAIA GRANDE - AVIAÇÃO
# Treinando modelo: PRAIA GRANDE-AVIAÇÃO
# Modelo Treinado: PRAIA GRANDE-AVIAÇÃO- MSE:26581
# iniciando: PRAIA GRANDE - VILA TUPI
# Treinando modelo: PRAIA GRANDE-VILA TUPI
# Modelo Treinado: PRAIA GRANDE-VILA TUPI- MSE:36511
# iniciando: PRAIA GRANDE - OCIAN
# Treinando modelo: PRAIA GRANDE-OCIAN
# Modelo Treinado: PRAIA GRANDE-OCIAN- MSE:44029
# iniciando: PRAIA GRANDE - VILA MIRIM
# Treinando modelo: PRAIA GRANDE-VILA MIRIM
# Modelo Treinado: PRAIA GRANDE-VILA MIRIM- MSE:73830
# iniciando: PRAIA GRANDE - MARACANÃ
# Treinando modelo: PRAIA GRANDE-MARACANÃ
# Modelo Treinado: PRAIA GRANDE-MARACANÃ- MSE:75952
# iniciando: PRAIA GRANDE - VILA CAIÇARA
# Treinando modelo: PRAIA GRANDE-VILA CAIÇARA
# Modelo Treinado: PRAIA GRANDE-VILA CAIÇARA- MSE:55633
# iniciando: PRAIA GRANDE - REAL
# Treinando modelo: PRAIA GRANDE-REAL
# Modelo Treinado: PRAIA GRANDE-REAL- MSE:29570
# iniciando: PRAIA GRANDE - BALNEÁRIO FLÓRIDA
# Treinando modelo: PRAIA GRANDE-BALNEÁRIO FLÓRIDA
# Modelo Treinado: PRAIA GRANDE-BALNEÁRIO FLÓRIDA- MSE:22162
# iniciando: PRAIA GRANDE - JARDIM SOLEMAR
# Treinando modelo: PRAIA GRANDE-JARDIM SOLEMAR
# Modelo Treinado: PRAIA GRANDE-JARDIM SOLEMAR- MSE:38226
# iniciando: SANTOS - PONTA DA PRAIA
# Treinando modelo: SANTOS-PONTA DA PRAIA
# Modelo Treinado: SANTOS-PONTA DA PRAIA- MSE:21740
# iniciando: SANTOS - APARECIDA
# Treinando modelo: SANTOS-APARECIDA
# Modelo Treinado: SANTOS-APARECIDA- MSE:15576
# iniciando: SANTOS - EMBARÉ
# Treinando modelo: SANTOS-EMBARÉ
# Modelo Treinado: SANTOS-EMBARÉ- MSE:16547
# iniciando: SANTOS - BOQUEIRÃO
# Treinando modelo: SANTOS-BOQUEIRÃO
# Modelo Treinado: SANTOS-BOQUEIRÃO- MSE:18200
# iniciando: SANTOS - GONZAGA
# Treinando modelo: SANTOS-GONZAGA
# Modelo Treinado: SANTOS-GONZAGA- MSE:16675
# iniciando: SANTOS - JOSÉ MENINO (R. OLAVO BILAC)
# Treinando modelo: SANTOS-JOSÉ MENINO (R. OLAVO BILAC)
# Modelo Treinado: SANTOS-JOSÉ MENINO (R. OLAVO BILAC)- MSE:16039
# iniciando: SANTOS - JOSÉ MENINO (R. FREDERICO OZANAN)
# Treinando modelo: SANTOS-JOSÉ MENINO (R. FREDERICO OZANAN)
# Modelo Treinado: SANTOS-JOSÉ MENINO (R. FREDERICO OZANAN)- MSE:20796
# iniciando: SÃO SEBASTIÃO - PRAINHA
# Treinando modelo: SÃO SEBASTIÃO-PRAINHA
# Modelo Treinado: SÃO SEBASTIÃO-PRAINHA- MSE:22828
# iniciando: SÃO SEBASTIÃO - CIGARRAS
# Treinando modelo: SÃO SEBASTIÃO-CIGARRAS
# Modelo Treinado: SÃO SEBASTIÃO-CIGARRAS- MSE:9824
# iniciando: SÃO SEBASTIÃO - SÃO FRANCISCO
# Treinando modelo: SÃO SEBASTIÃO-SÃO FRANCISCO
# Modelo Treinado: SÃO SEBASTIÃO-SÃO FRANCISCO- MSE:18968
# iniciando: SÃO SEBASTIÃO - ARRASTÃO
# Treinando modelo: SÃO SEBASTIÃO-ARRASTÃO
# Modelo Treinado: SÃO SEBASTIÃO-ARRASTÃO- MSE:11936
# iniciando: SÃO SEBASTIÃO - PONTAL DA CRUZ
# Treinando modelo: SÃO SEBASTIÃO-PONTAL DA CRUZ
# Modelo Treinado: SÃO SEBASTIÃO-PONTAL DA CRUZ- MSE:26131
# iniciando: SÃO SEBASTIÃO - DESERTA
# Treinando modelo: SÃO SEBASTIÃO-DESERTA
# Modelo Treinado: SÃO SEBASTIÃO-DESERTA- MSE:20204
# iniciando: SÃO SEBASTIÃO - PORTO GRANDE
# Treinando modelo: SÃO SEBASTIÃO-PORTO GRANDE
# Modelo Treinado: SÃO SEBASTIÃO-PORTO GRANDE- MSE:18561
# iniciando: SÃO SEBASTIÃO - PRETA DO NORTE
# Treinando modelo: SÃO SEBASTIÃO-PRETA DO NORTE
# Modelo Treinado: SÃO SEBASTIÃO-PRETA DO NORTE- MSE:21550
# iniciando: SÃO SEBASTIÃO - GRANDE
# Treinando modelo: SÃO SEBASTIÃO-GRANDE
# Modelo Treinado: SÃO SEBASTIÃO-GRANDE- MSE:3149
# iniciando: SÃO SEBASTIÃO - BAREQUEÇABA
# Treinando modelo: SÃO SEBASTIÃO-BAREQUEÇABA
# Modelo Treinado: SÃO SEBASTIÃO-BAREQUEÇABA- MSE:2196
# iniciando: SÃO SEBASTIÃO - GUAECÁ
# Treinando modelo: SÃO SEBASTIÃO-GUAECÁ
# Modelo Treinado: SÃO SEBASTIÃO-GUAECÁ- MSE:1229
# iniciando: SÃO SEBASTIÃO - TOQUE-TOQUE GRANDE
# Treinando modelo: SÃO SEBASTIÃO-TOQUE-TOQUE GRANDE
# Modelo Treinado: SÃO SEBASTIÃO-TOQUE-TOQUE GRANDE- MSE:2381
# iniciando: SÃO SEBASTIÃO - TOQUE-TOQUE PEQUENO
# Treinando modelo: SÃO SEBASTIÃO-TOQUE-TOQUE PEQUENO
# Modelo Treinado: SÃO SEBASTIÃO-TOQUE-TOQUE PEQUENO- MSE:2723
# iniciando: SÃO SEBASTIÃO - SANTIAGO
# Treinando modelo: SÃO SEBASTIÃO-SANTIAGO
# Modelo Treinado: SÃO SEBASTIÃO-SANTIAGO- MSE:21
# iniciando: SÃO SEBASTIÃO - PAÚBA
# Treinando modelo: SÃO SEBASTIÃO-PAÚBA
# Modelo Treinado: SÃO SEBASTIÃO-PAÚBA- MSE:644
# iniciando: SÃO SEBASTIÃO - MARESIAS
# Treinando modelo: SÃO SEBASTIÃO-MARESIAS
# Modelo Treinado: SÃO SEBASTIÃO-MARESIAS- MSE:950
# iniciando: SÃO SEBASTIÃO - BOIÇUCANGA
# Treinando modelo: SÃO SEBASTIÃO-BOIÇUCANGA
# Modelo Treinado: SÃO SEBASTIÃO-BOIÇUCANGA- MSE:49344
# iniciando: SÃO SEBASTIÃO - CAMBURIZINHO
# Treinando modelo: SÃO SEBASTIÃO-CAMBURIZINHO
# Modelo Treinado: SÃO SEBASTIÃO-CAMBURIZINHO- MSE:2770
# iniciando: SÃO SEBASTIÃO - CAMBURI
# Treinando modelo: SÃO SEBASTIÃO-CAMBURI
# Modelo Treinado: SÃO SEBASTIÃO-CAMBURI- MSE:5397
# iniciando: SÃO SEBASTIÃO - BALEIA
# Treinando modelo: SÃO SEBASTIÃO-BALEIA
# Modelo Treinado: SÃO SEBASTIÃO-BALEIA- MSE:2638
# iniciando: SÃO SEBASTIÃO - SAÍ
# Treinando modelo: SÃO SEBASTIÃO-SAÍ
# Modelo Treinado: SÃO SEBASTIÃO-SAÍ- MSE:13054
# iniciando: SÃO SEBASTIÃO - PRETA
# Treinando modelo: SÃO SEBASTIÃO-PRETA
# Modelo Treinado: SÃO SEBASTIÃO-PRETA- MSE:7606
# iniciando: SÃO SEBASTIÃO - JUQUEÍ (TRAV. SIMÃO FAUSTINO)
# Treinando modelo: SÃO SEBASTIÃO-JUQUEÍ (TRAV. SIMÃO FAUSTINO)
# Modelo Treinado: SÃO SEBASTIÃO-JUQUEÍ (TRAV. SIMÃO FAUSTINO)- MSE:4045
# iniciando: SÃO SEBASTIÃO - JUQUEÍ (R. CRISTIANA)
# Treinando modelo: SÃO SEBASTIÃO-JUQUEÍ (R. CRISTIANA)
# Modelo Treinado: SÃO SEBASTIÃO-JUQUEÍ (R. CRISTIANA)- MSE:9937
# iniciando: SÃO SEBASTIÃO - UNA
# Treinando modelo: SÃO SEBASTIÃO-UNA
# Modelo Treinado: SÃO SEBASTIÃO-UNA- MSE:21424
# iniciando: SÃO SEBASTIÃO - ENGENHO
# Treinando modelo: SÃO SEBASTIÃO-ENGENHO
# Modelo Treinado: SÃO SEBASTIÃO-ENGENHO- MSE:4208
# iniciando: SÃO SEBASTIÃO - JURÉIA DO NORTE
# Treinando modelo: SÃO SEBASTIÃO-JURÉIA DO NORTE
# Modelo Treinado: SÃO SEBASTIÃO-JURÉIA DO NORTE- MSE:2238
# iniciando: SÃO SEBASTIÃO - BORACÉIA - NORTE
# Treinando modelo: SÃO SEBASTIÃO-BORACÉIA - NORTE
# Modelo Treinado: SÃO SEBASTIÃO-BORACÉIA - NORTE- MSE:8996
# iniciando: SÃO SEBASTIÃO - BORACÉIA - R. CUBATÃO
# Treinando modelo: SÃO SEBASTIÃO-BORACÉIA - R. CUBATÃO
# Modelo Treinado: SÃO SEBASTIÃO-BORACÉIA - R. CUBATÃO- MSE:10670
# iniciando: SÃO VICENTE - PRAIA DA DIVISA
# Treinando modelo: SÃO VICENTE-PRAIA DA DIVISA
# Modelo Treinado: SÃO VICENTE-PRAIA DA DIVISA- MSE:20643
# iniciando: SÃO VICENTE - ITARARÉ (POSTO 2)
# Treinando modelo: SÃO VICENTE-ITARARÉ (POSTO 2)
# Modelo Treinado: SÃO VICENTE-ITARARÉ (POSTO 2)- MSE:12967
# iniciando: SÃO VICENTE - PRAIA DA ILHA PORCHAT
# Treinando modelo: SÃO VICENTE-PRAIA DA ILHA PORCHAT
# Modelo Treinado: SÃO VICENTE-PRAIA DA ILHA PORCHAT- MSE:8358
# iniciando: SÃO VICENTE - MILIONÁRIOS
# Treinando modelo: SÃO VICENTE-MILIONÁRIOS
# Modelo Treinado: SÃO VICENTE-MILIONÁRIOS- MSE:290299
# iniciando: SÃO VICENTE - GONZAGUINHA
# Treinando modelo: SÃO VICENTE-GONZAGUINHA
# Modelo Treinado: SÃO VICENTE-GONZAGUINHA- MSE:182279
# iniciando: SÃO VICENTE - PRAINHA (AV. SANTINO BRITO)
# Treinando modelo: SÃO VICENTE-PRAINHA (AV. SANTINO BRITO)
# Modelo Treinado: SÃO VICENTE-PRAINHA (AV. SANTINO BRITO)- MSE:286449
# iniciando: UBATUBA - PICINGUABA
# Treinando modelo: UBATUBA-PICINGUABA
# Modelo Treinado: UBATUBA-PICINGUABA- MSE:7436
# iniciando: UBATUBA - FÉLIX
# Treinando modelo: UBATUBA-FÉLIX
# Modelo Treinado: UBATUBA-FÉLIX- MSE:2005
# iniciando: UBATUBA - ITAMAMBUCA
# Treinando modelo: UBATUBA-ITAMAMBUCA
# Modelo Treinado: UBATUBA-ITAMAMBUCA- MSE:71
# iniciando: UBATUBA - RIO  ITAMAMBUCA
# Treinando modelo: UBATUBA-RIO  ITAMAMBUCA
# Modelo Treinado: UBATUBA-RIO  ITAMAMBUCA- MSE:17140
# iniciando: UBATUBA - VERMELHA DO NORTE
# Treinando modelo: UBATUBA-VERMELHA DO NORTE
# Modelo Treinado: UBATUBA-VERMELHA DO NORTE- MSE:0
# iniciando: UBATUBA - PEREQUÊ-AÇU
# Treinando modelo: UBATUBA-PEREQUÊ-AÇU
# Modelo Treinado: UBATUBA-PEREQUÊ-AÇU- MSE:3190
# iniciando: UBATUBA - IPEROIG
# Treinando modelo: UBATUBA-IPEROIG
# Modelo Treinado: UBATUBA-IPEROIG- MSE:7002
# iniciando: UBATUBA - ITAGUÁ (No 230 DA AV. LEOVEGILDO)
# Treinando modelo: UBATUBA-ITAGUÁ (No 230 DA AV. LEOVEGILDO)
# Modelo Treinado: UBATUBA-ITAGUÁ (No 230 DA AV. LEOVEGILDO)- MSE:25641
# iniciando: UBATUBA - ITAGUA (No1724 DA AV. LEOVEGILDO)
# Treinando modelo: UBATUBA-ITAGUA (No1724 DA AV. LEOVEGILDO)
# Modelo Treinado: UBATUBA-ITAGUA (No1724 DA AV. LEOVEGILDO)- MSE:38633
# iniciando: UBATUBA - TENÓRIO
# Treinando modelo: UBATUBA-TENÓRIO
# Modelo Treinado: UBATUBA-TENÓRIO- MSE:15
# iniciando: UBATUBA - VERMELHA
# Treinando modelo: UBATUBA-VERMELHA
# Modelo Treinado: UBATUBA-VERMELHA- MSE:457
# iniciando: UBATUBA - GRANDE
# Treinando modelo: UBATUBA-GRANDE
# Modelo Treinado: UBATUBA-GRANDE- MSE:2
# iniciando: UBATUBA - TONINHAS
# Treinando modelo: UBATUBA-TONINHAS
# Modelo Treinado: UBATUBA-TONINHAS- MSE:305
# iniciando: UBATUBA - ENSEADA
# Treinando modelo: UBATUBA-ENSEADA
# Modelo Treinado: UBATUBA-ENSEADA- MSE:6153
# iniciando: UBATUBA - SANTA RITA
# Treinando modelo: UBATUBA-SANTA RITA
# Modelo Treinado: UBATUBA-SANTA RITA- MSE:13190
# iniciando: UBATUBA - PEREQUÊ-MIRIM
# Treinando modelo: UBATUBA-PEREQUÊ-MIRIM
# Modelo Treinado: UBATUBA-PEREQUÊ-MIRIM- MSE:20467
# iniciando: UBATUBA - SUNUNGA
# Treinando modelo: UBATUBA-SUNUNGA
# Modelo Treinado: UBATUBA-SUNUNGA- MSE:2937
# iniciando: UBATUBA - LÁZARO
# Treinando modelo: UBATUBA-LÁZARO
# Modelo Treinado: UBATUBA-LÁZARO- MSE:12681
# iniciando: UBATUBA - DOMINGAS DIAS
# Treinando modelo: UBATUBA-DOMINGAS DIAS
# Modelo Treinado: UBATUBA-DOMINGAS DIAS- MSE:11
# iniciando: UBATUBA - DURA
# Treinando modelo: UBATUBA-DURA
# Modelo Treinado: UBATUBA-DURA- MSE:8623
# iniciando: UBATUBA - LAGOINHA (R. ENGENHO VELHO)
# Treinando modelo: UBATUBA-LAGOINHA (R. ENGENHO VELHO)
# Modelo Treinado: UBATUBA-LAGOINHA (R. ENGENHO VELHO)- MSE:1309
# iniciando: UBATUBA - LAGOINHA (CAMPING)
# Treinando modelo: UBATUBA-LAGOINHA (CAMPING)
# Modelo Treinado: UBATUBA-LAGOINHA (CAMPING)- MSE:287
# iniciando: UBATUBA - SAPÉ
# Treinando modelo: UBATUBA-SAPÉ
# Modelo Treinado: UBATUBA-SAPÉ- MSE:2338
# iniciando: UBATUBA - MARANDUBA
# Treinando modelo: UBATUBA-MARANDUBA
# Modelo Treinado: UBATUBA-MARANDUBA- MSE:3563
